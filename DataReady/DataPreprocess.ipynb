# %%
import pandas as pd
import math

# %%
temp=pd.read_csv('./Project/male_players.csv')
# Out:
# /Users/liuziye/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (108) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
drop_list=['attacking_crossing',
 'attacking_finishing',
 'attacking_heading_accuracy',
 'attacking_short_passing',
 'attacking_volleys',
 'skill_dribbling',
 'skill_curve',
 'skill_fk_accuracy',
 'skill_long_passing',
 'skill_ball_control',
 'movement_acceleration',
 'movement_sprint_speed',
 'movement_agility',
 'movement_reactions',
 'movement_balance',
 'power_shot_power',
 'power_jumping',
 'power_stamina',
 'power_strength',
 'power_long_shots',
 'mentality_aggression',
 'mentality_interceptions',
 'mentality_positioning',
 'mentality_vision',
 'mentality_penalties',
 'mentality_composure',
 'defending_marking_awareness',
 'defending_standing_tackle',
 'defending_sliding_tackle',
 'goalkeeping_diving',
 'goalkeeping_handling',
 'goalkeeping_kicking',
 'goalkeeping_positioning',
 'goalkeeping_reflexes',
 'goalkeeping_speed',
 'ls',
 'st',
 'rs',
 'lw',
 'lf',
 'cf',
 'rf',
 'rw',
 'lam',
 'cam',
 'ram',
 'lm',
 'lcm',
 'cm',
 'rcm',
 'rm',
 'lwb',
 'ldm',
 'cdm',
 'rdm',
 'rwb',
 'lb',
 'lcb',
 'cb',
 'rcb',
 'rb',
 'gk',
 'player_face_url']

# %%
temp1=temp.drop(columns=drop_list)

# %%
temp1.loc[:,'player_positions']=temp1.player_positions.apply(lambda x:str(x).replace(",","-"))
temp1.loc[:,'player_tags']=temp1.player_tags.apply(lambda x:str(x).replace(",","-"))
temp1.loc[:,'player_traits']=temp1.player_traits.apply(lambda x:str(x).replace(",","-"))

# %%
temp1.loc[:,'league_id']=temp1.league_id.apply(lambda x:str(int(x)) if not math.isnan(x) else float('nan'))
temp1.loc[:,'club_team_id']=temp1.club_team_id.apply(lambda x:str(int(x)) if not math.isnan(x) else float('nan'))
temp1.loc[:,'nation_team_id']=temp1.nation_team_id.apply(lambda x:str(int(x)) if not math.isnan(x) else float('nan'))
temp1.loc[:,'club_contract_valid_until_year']=temp1.club_contract_valid_until_year.apply(lambda x:str(int(x)) if not math.isnan(x) else float('nan'))
temp1.loc[:,'nation_jersey_number']=temp1.nation_jersey_number.apply(lambda x:str(int(x)) if not math.isnan(x) else float('nan'))

# %%
temp1
# Out:
#           player_id                                player_url  fifa_version  \
# 0            158023        /player/158023/lionel-messi/230009            23
# 1            165153       /player/165153/karim-benzema/230009            23
# 2            188545  /player/188545/robert-lewandowski/230009            23
# 3            192985     /player/192985/kevin-de-bruyne/230009            23
# 4            231747       /player/231747/kylian-mbappe/230009            23
# ...             ...                                       ...           ...
# 10003585     222997        /player/222997/marcus-maier/150001            15
# 10003586     225011        /player/225011/lee-marshall/150001            15
# 10003587     220806        /player/220806/ellis-redman/150001            15
# 10003588     201197        /player/201197/paul-tisdale/150001            15
# 10003589     217591         /player/217591/piotr-zemlo/150001            15
#
# ...

# %%
temp1.to_csv('./Project/male_players_id_fix.csv',index=False,header=False)

# %%
temp1.to_csv('./Project/male_players_less.csv',index=False,header=False)

# %%
pd.read_csv('./Project/male_teams.csv')
# Out:
# /Users/liuziye/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py:3441: DtypeWarning: Columns (37,41) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)
#         team_id                             team_url  fifa_version  \
# 0            10      /team/10/manchester-city/230009            23
# 1            73  /team/73/paris-saint-germain/230009            23
# 2           243         /team/243/real-madrid/230009            23
# 3          1337            /team/1337/germany/230009            23
# 4             5               /team/5/chelsea/230009            23
# ...         ...                                  ...           ...
# 385050      305         /team/305/bohemian-fc/150001            15
# 385051     1572    /team/1572/drogheda-united/150001            15
# 385052      838      /team/838/bray-wanderers/150001            15
# ...

# %%
import pandas as pd
temp=pd.read_csv('./Project/male_players_less.csv')

# %%
temp
# Out:
#           158023        /player/158023/lionel-messi/230009  23  9  2023-01-13  \
# 0         165153       /player/165153/karim-benzema/230009  23  9  2023-01-13
# 1         188545  /player/188545/robert-lewandowski/230009  23  9  2023-01-13
# 2         192985     /player/192985/kevin-de-bruyne/230009  23  9  2023-01-13
# 3         231747       /player/231747/kylian-mbappe/230009  23  9  2023-01-13
# 4         192119    /player/192119/thibaut-courtois/230009  23  9  2023-01-13
# ...          ...                                       ...  .. ..         ...
# 10003584  222997        /player/222997/marcus-maier/150001  15  1  2014-08-29
# 10003585  225011        /player/225011/lee-marshall/150001  15  1  2014-08-29
# 10003586  220806        /player/220806/ellis-redman/150001  15  1  2014-08-29
# 10003587  201197        /player/201197/paul-tisdale/150001  15  1  2014-08-29
# 10003588  217591         /player/217591/piotr-zemlo/150001  15  1  2014-08-29
#
# ...

# %%
temp2=temp.head(100000)
temp2.to_csv('./Project/temp_test.csv',index=False,header=False)
